# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(-0.0030699467631492895), np.float64(1.018232392385591))

# %%
# %timeit np.random.randn(1000)
# Out:
# 13.3 μs ± 57.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %%time 
model.fit(X_train, y_train, epochs=10)
# Out:
# CPU times: user 0 ns, sys: 4 μs, total: 4 μs
# Wall time: 7.15 μs
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'model.fit(X_train, y_train, epochs=10)\n')
#
# File <timed eval>:1
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# NameError: name 'model' is not defined

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(data, bins=30)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Distribution of Random Data")
plt.show()

# %%
# !uv pip install scikit-learn
# Out:
# Using Python 3.12.13 environment at: /home/plx1lyns/ai-engineering-from-scratch/.venv
# Resolved 6 packages in 522ms
# ⠙ Preparing packages... (0/5)
# ⠙ Preparing packages... (0/5)-------------------     0 B/18.20 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/18.20 KiB
# threadpoolctl        ------------------------------     0 B/18.20 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/443.18 KiB
# threadpoolctl        ------------------------------     0 B/18.20 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/443.18 KiB
# threadpoolctl        ------------------------------     0 B/18.20 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/443.18 KiB
# threadpoolctl        ------------------------------     0 B/18.20 KiB
# narwhals             ------------------------------     0 B/443.18 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/33.60 MiB
# threadpoolctl        ------------------------------     0 B/18.20 KiB
# narwhals             ------------------------------     0 B/443.18 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/33.60 MiB
# threadpoolctl        ------------------------------     0 B/18.20 KiB
# narwhals             ------------------------------     0 B/443.18 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/33.60 MiB
# threadpoolctl        ------------------------------     0 B/18.20 KiB
# narwhals             ------------------------------     0 B/443.18 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/33.60 MiB
# threadpoolctl        ------------------------------     0 B/18.20 KiB
# joblib               ------------------------------     0 B/301.83 KiB
# narwhals             ------------------------------     0 B/443.18 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/33.60 MiB
# threadpoolctl        ------------------------------     0 B/18.20 KiB
# joblib               ------------------------------     0 B/301.83 KiB
# narwhals             ------------------------------ 14.83 KiB/443.18 KiB
# ⠙ Preparing packages... (0/5)-------------------     0 B/33.60 MiB
# threadpoolctl        ------------------------------     0 B/18.20 KiB
# joblib               ------------------------------     0 B/301.83 KiB
# narwhals             ------------------------------ 14.83 KiB/443.18 KiB
# ⠙ Preparing packages... (0/5)------------------- 14.83 KiB/33.60 MiB
# threadpoolctl        ------------------------------     0 B/18.20 KiB
# joblib               ------------------------------ 14.81 KiB/301.83 KiB
# narwhals             ------------------------------ 14.83 KiB/443.18 KiB
# ⠙ Preparing packages... (0/5)------------------- 14.83 KiB/33.60 MiB
# threadpoolctl        ------------------------------ 16.00 KiB/18.20 KiB
# joblib               ------------------------------ 14.81 KiB/301.83 KiB
# narwhals             ------------------------------ 14.83 KiB/443.18 KiB
# ⠙ Preparing packages... (0/5)------------------- 14.83 KiB/33.60 MiB
# threadpoolctl        ------------------------------ 18.20 KiB/18.20 KiB
# joblib               ------------------------------ 14.81 KiB/301.83 KiB
# narwhals             ------------------------------ 14.83 KiB/443.18 KiB
# ⠙ Preparing packages... (0/5)------------------- 14.83 KiB/33.60 MiB
# threadpoolctl        ------------------------------ 18.20 KiB/18.20 KiB
# joblib               ------------------------------ 14.81 KiB/301.83 KiB
# narwhals             ------------------------------ 14.83 KiB/443.18 KiB
# ⠙ Preparing packages... (0/5)------------------- 14.83 KiB/33.60 MiB
# joblib               ------------------------------ 14.81 KiB/301.83 KiB
# narwhals             ------------------------------ 14.83 KiB/443.18 KiB
# ⠙ Preparing packages... (0/5)------------------- 14.83 KiB/33.60 MiB
# joblib               ------------------------------ 14.81 KiB/301.83 KiB
# narwhals             ------------------------------ 30.83 KiB/443.18 KiB
# ⠙ Preparing packages... (0/5)------------------- 14.83 KiB/33.60 MiB
# joblib               ------------------------------ 14.81 KiB/301.83 KiB
# narwhals             ------------------------------ 30.83 KiB/443.18 KiB
# ⠙ Preparing packages... (0/5)------------------- 30.83 KiB/33.60 MiB
# joblib               ------------------------------ 30.81 KiB/301.83 KiB
# narwhals             ------------------------------ 46.83 KiB/443.18 KiB
# ⠙ Preparing packages... (0/5)------------------- 46.83 KiB/33.60 MiB
# joblib               ------------------------------ 124.13 KiB/301.83 KiB
# narwhals             ------------------------------ 124.40 KiB/443.18 KiB
# scikit-learn         ------------------------------ 111.23 KiB/8.71 MiB
# ⠙ Preparing packages... (0/5)------------------- 125.86 KiB/33.60 MiB
# narwhals             ------------------------------ 380.40 KiB/443.18 KiB
# scikit-learn         ------------------------------ 383.33 KiB/8.71 MiB
# ⠙ Preparing packages... (0/5)------------------- 381.86 KiB/33.60 MiB
# narwhals             ------------------------------ 412.40 KiB/443.18 KiB
# scikit-learn         ------------------------------ 383.33 KiB/8.71 MiB
# ⠹ Preparing packages... (2/5)------------------- 397.86 KiB/33.60 MiB
# scikit-learn         ------------------------------ 511.33 KiB/8.71 MiB
# ⠹ Preparing packages... (2/5)------------------- 461.86 KiB/33.60 MiB
# scikit-learn         ------------------------------ 1.34 MiB/8.71 MiB
# ⠹ Preparing packages... (2/5)------------------- 1.36 MiB/33.60 MiB
# scikit-learn         ------------------------------ 2.22 MiB/8.71 MiB
# ⠹ Preparing packages... (2/5)------------------- 2.24 MiB/33.60 MiB
# scikit-learn         ------------------------------ 2.69 MiB/8.71 MiB
# ⠹ Preparing packages... (2/5)------------------- 4.06 MiB/33.60 MiB
# scikit-learn         ------------------------------ 3.36 MiB/8.71 MiB
# ⠸ Preparing packages... (3/5)------------------- 4.21 MiB/33.60 MiB
# scikit-learn         ------------------------------ 4.29 MiB/8.71 MiB
# ⠸ Preparing packages... (3/5)------------------- 6.37 MiB/33.60 MiB
# scikit-learn         ------------------------------ 5.90 MiB/8.71 MiB
# ⠸ Preparing packages... (3/5)------------------- 7.69 MiB/33.60 MiB
# scikit-learn         ------------------------------ 6.78 MiB/8.71 MiB
# ⠸ Preparing packages... (3/5)------------------- 9.70 MiB/33.60 MiB
# scikit-learn         ------------------------------ 7.92 MiB/8.71 MiB
# ⠼ Preparing packages... (3/5)------------------- 10.97 MiB/33.60 MiB
# scikit-learn         ------------------------------ 8.67 MiB/8.71 MiB
# ⠼ Preparing packages... (3/5)------------------- 13.19 MiB/33.60 MiB
# ⠼ Preparing packages... (3/5)m------------------ 13.55 MiB/33.60 MiB
# ⠼ Preparing packages... (3/5)m------------------ 14.50 MiB/33.60 MiB
# ⠼ Preparing packages... (3/5)--------------- 17.06 MiB/33.60 MiB
# ⠴ Preparing packages... (4/5)0m------------- 19.06 MiB/33.60 MiB
# ⠴ Preparing packages... (4/5)30m------------ 21.14 MiB/33.60 MiB
# ⠴ Preparing packages... (4/5)---------- 23.20 MiB/33.60 MiB
# ⠴ Preparing packages... (4/5)---------- 24.39 MiB/33.60 MiB
# ⠦ Preparing packages... (4/5)---------- 27.22 MiB/33.60 MiB
# ⠦ Preparing packages... (4/5)---------- 29.37 MiB/33.60 MiB
# ⠦ Preparing packages... (4/5)---------- 31.12 MiB/33.60 MiB
# Prepared 5 packages in 1.17s
# Installed 5 packages in 66ms
#  + joblib==1.5.3
#  + narwhals==2.22.0
#  + scikit-learn==1.9.0
#  + scipy==1.17.1
#  + threadpoolctl==3.6.0

# %%
# %env test_env=10
# %env test_env
# Out:
# env: test_env=10
# '10'

# %%
import pandas as pd

df = pd.DataFrame({
    "model": ["Linear", "Random Forest", "Neural Net"],
    "accuracy": [0.72, 0.89, 0.94],
    "training_time": [0.1, 2.3, 45.6]
})
df
# Out:
#            model  accuracy  training_time
# 0         Linear      0.72            0.1
# 1  Random Forest      0.89            2.3
# 2     Neural Net      0.94           45.6

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.title("Inline Plot")
plt.show()
